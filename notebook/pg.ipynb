# %%
import random
from utils import draw_state
import numpy as np
from env import SimpleARGEnvironment
# from rollout_worker_arg import RolloutWorker
# from tb_gfn import TBGFlowNetGenerator
# from env import Trajectory

from utils import load_sequences

# %%
Ne = 10000
r_per_bp = 2e-8
mu_per_bp = 2e-8

dataset_path="validation/fasta/sim_l25kb_0.fa"

sequences = load_sequences(dataset_path)
env = SimpleARGEnvironment(
        num_sequences=len(sequences),
        population_size=Ne,
        recombination_rate=r_per_bp,
        mutation_rate=mu_per_bp,
        sequences=sequences,
        seed=7,
        bp_per_blocks=1
    )

# generator = TBGFlowNetGenerator(env, init_z_sample_count=4)
# rollout_worker = RolloutWorker(env, verbose=True)
# batch_size = 2

# %%
traj = env.sample(16)
