# %%
import sys
from pathlib import Path

import pandas as pd
from scripts.plot_point_accuracy import load_truth_tracks

VALIDATION_DIR = Path(".").resolve()
TRUTH_DIR = VALIDATION_DIR / "tcoalmsp" / "rep0"
TRUTH_PREFIX = "sim_l1mb_0"
NE = 10000

truth_tracks = load_truth_tracks(TRUTH_DIR, TRUTH_PREFIX, NE)
print(f"Loaded {len(truth_tracks)} sample-pair truth tracks from {TRUTH_DIR}")
# Out:
# Loaded 28 sample-pair truth tracks from /Users/pratik/Documents/work/aim3/simpliied/arg/validation/tcoalmsp/rep0

# %%
rows = []
for (s1, s2), intervals in sorted(truth_tracks.items()):
    pair = f"{s1}-{s2}"
    for interval in intervals:
        rows.append(
            {
                "pair": pair,
                "left": interval.left,
                "right": interval.right,
                "tcoal_2ne": interval.tcoal_2ne,
                "tcoal_raw": interval.tcoal_2ne * 2 * NE,
            }
        )

df = pd.DataFrame(rows).sort_values(["pair", "left"]).reset_index(drop=True)
print(f"Total intervals: {len(df)}")
df
# Out:
# Total intervals: 42644
#       pair      left      right  tcoal_2ne     tcoal_raw
# 0      0-1       0.0     1181.0   0.816495  16329.907925
# 1      0-1    1181.0     1839.0   0.816495  16329.907925
# 2      0-1    1839.0     3101.0   0.816495  16329.907925
# 3      0-1    3101.0     4133.0   0.816495  16329.907925
# 4      0-1    4133.0     5318.0   1.919435  38388.706969
# ...    ...       ...        ...        ...           ...
# 42639  6-7  997511.0   998602.0   0.482064   9641.282971
# 42640  6-7  998602.0   998651.0   0.482064   9641.282971
# 42641  6-7  998651.0   998889.0   0.482064   9641.282971
# 42642  6-7  998889.0   999711.0   0.482064   9641.282971
# 42643  6-7  999711.0  1000000.0   0.482064   9641.282971
#
# [42644 rows x 5 columns]

# %%
unique_raw = sorted(df["tcoal_raw"].unique())
unique_2ne = sorted(df["tcoal_2ne"].unique())

print(f"Globally unique raw coalescence times: {len(unique_raw)}")
print(unique_raw)
print()
print(f"Globally unique t/(2Ne) coalescence times: {len(unique_2ne)}")
print(unique_2ne)
print()

pair_stats = (
    df.groupby("pair")
    .agg(
        n_intervals=("left", "size"),
        n_unique_times=("tcoal_raw", "nunique"),
        min_tcoal_raw=("tcoal_raw", "min"),
        max_tcoal_raw=("tcoal_raw", "max"),
    )
    .reset_index()
)
print("Per-pair summary:")
display(pair_stats)

selected_pair = "0-1"
pair_times = sorted(df.loc[df["pair"] == selected_pair, "tcoal_raw"].unique())
print(f"\nUnique raw times for pair {selected_pair} ({len(pair_times)} values):")
print(pair_times)
# Out:
# Globally unique raw coalescence times: 1058
# [np.float64(45.368671039957874), np.float64(132.1314463006347), np.float64(210.97486863914287), np.float64(231.43839419709198), np.float64(252.21421120901218), np.float64(400.5111520822349), np.float64(423.1975490003994), np.float64(617.091607504236), np.float64(881.3420371028924), np.float64(910.24647521052), np.float64(948.3056820740503), np.float64(953.5388198601775), np.float64(962.9426983144235), np.float64(974.3100763569956), np.float64(994.2350325292797), np.float64(1046.2760494608215), np.float64(1092.9843783688439), np.float64(1114.5637874568363), np.float64(1148.714128715633), np.float64(1173.5576682149879), np.float64(1191.767136741216), np.float64(1192.72165249634), np.float64(1246.909984574607), np.float64(1271.6368898745254), np.float64(1272.624151294602), np.float64(1274.465625206651),
(12656.894848039674), np.float64(12687.107025503577), np.float64(12898.948778473985), np.float64(13287.813113130023), np.float64(13457.927825597268), np.float64(13614.862572769196), np.float64(13890.213844935017), np.float64(13988.059051601054), np.float64(14057.69824965018), np.float64(14074.468475842192), np.float64(14318.957244931142), np.float64(14537.225844035333), np.float64(14687.705958764373), np.float64(14754.810967306043), np.float64(14789.789719797664), np.float64(15075.644379480254), np.float64(15264.071633822403), np.float64(15630.162545831625), np.float64(15638.79168419116), np.float64(15740.719287459124), np.float64(16029.444542817442), np.float64(16043.412547416658), np.float64(16329.907924518753), np.float64(16419.182238693058), np.float64(16501.144743397075), np.float64(16527.011160157566), np.float64(16535.039181515043), np.float64(16875.178122779147), np.float64(16883.57217326004), np.float64(17029.119065153976), np.float64(17047.94522443561), np.float64(17125.940298614238), np.float64(17343.33624925641), np.float64(17377.124507286444), np.float64(17445.790717391734), np.float64(17710.654349358156), np.float64(17941.075608540352), np.float64(18036.652188072847), np.float64(18113.85682422901), np.float64(18201.218728443455), np.float64(18225.023759318166), np.float64(18489.69542146519), np.float64(18567.70617916619), np.float64(18681.730425623115), np.float64(18752.839030469284), np.float64(18865.229675496797), np.float64(19222.434435846022), np ...

# %% [markdown]
# ### Inferred trees (`example.trees`)
#
# **Time units:** msprime truth stores node/tmrca times in **generations** (raw values ~10³–10⁵), then validation divides by `2*Ne` to get **t/(2Ne)**.
#
# The GFN export in `env.py` now writes learned node times in **generations** and sets `time_units="generations"`, so inferred trees should be divided by `2*Ne` exactly like truth.

# %%
import tskit
from scripts.plot_point_accuracy import TruthInterval

INFERRED_TREES = "../test_run_new/args/arg_000001.trees"
pairs = list(truth_tracks.keys())


def load_inferred_tracks_from_trees(trees_path, pairs):
    """GFN-inferred trees store tmrca in generations, matching msprime truth."""
    ts = tskit.load(str(trees_path))
    scale = 2.0 * NE
    samples = ts.samples()
    tracks = {pair: [] for pair in pairs}
    for tree in ts.trees():
        left, right = tree.interval
        if right <= left:
            continue
        for pair in pairs:
            tcoal_2ne = float(tree.tmrca(samples[pair[0]], samples[pair[1]]) / scale)
            tracks[pair].append(
                TruthInterval(left=float(left), right=float(right), tcoal_2ne=tcoal_2ne)
            )
    return tracks


inferred_tracks = load_inferred_tracks_from_trees(INFERRED_TREES, pairs)
print(f"Loaded {len(inferred_tracks)} sample-pair inferred tracks from {INFERRED_TREES}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 26
#      20             tracks[pair].append(
#      21                 TruthInterval(left=float(left), right=float(right), tcoal_2ne=tcoal_2ne)
#      22             )
#      23     return tracks
# ---> 26 inferred_tracks = load_inferred_tracks_from_trees(INFERRED_TREES, pairs)
#      27 print(f"Loaded {len(inferred_tracks)} sample-pair inferred tracks from {INFERRED_TREES}")
#
# Cell In[6], line 10, in load_inferred_tracks_from_trees(trees_path, pairs)
#       8 def load_inferred_tracks_from_trees(trees_path, pairs):
#       9     """GFN-inferred trees store tmrca in generations, matching msprime truth."""
# ---> 10     ts = tskit.load(str(trees_path))
#      11     scale = 2.0 * NE
#      12     samples = ts.samples()
#
# File /opt/anaconda3/envs/phylogfn/lib/python3.10/site-packages/tskit/trees.py:3450, in load(file, skip_tables, skip_reference_sequence)
#    3427 def load(file, *, skip_tables=False, skip_reference_sequence=False):
#    3428     """
#    3429     Return a :class:`TreeSequence` instance loaded from the specified file object or
#    3430     path. The file must be in the
#    (...)
#    3448     :rtype: :class:`tskit.TreeSequence`
#    3449     """
# -> 3450     return TreeSequence.load(
#    3451         file, skip_tables=skip_tables, skip_reference_sequence=skip_reference_sequence
#    3452     )
#
# File /opt/anaconda3/envs/phylogfn/lib/python3.10/site-packages/tskit/trees.py:4277, in TreeSequence.load(cls, file_or_path, skip_tables, skip_reference_sequence)
#    4275 @classmethod
#    4276 def load(cls, file_or_path, *, skip_tables=False, skip_reference_sequence=False):
# -> 4277     file, local_file = util.convert_file_like_to_open_file(file_or_path, "rb")
#    4278     try:
#    4279         ts = _tskit.TreeSequence()
#
# File /opt/anaconda3/envs/phylogfn/lib/python3.10/site-packages/tskit/util.py:812, in convert_file_like_to_open_file(file_like, mode)
#     809 try:
#     810     # First, see if we can interpret the argument as a pathlike object.
#     811     path = os.fspath(file_like)
# --> 812     _file = open(path, mode)
#     813 except TypeError:
#     814     pass
#
# FileNotFoundError: [Errno 2] No such file or directory: '../test_run_new/args/arg_000001.trees'

# %%
inferred_rows = []
for (s1, s2), intervals in sorted(inferred_tracks.items()):
    pair = f"{s1}-{s2}"
    for interval in intervals:
        inferred_rows.append(
            {
                "pair": pair,
                "left": interval.left,
                "right": interval.right,
                "tcoal_2ne": interval.tcoal_2ne,
                "tcoal_raw": interval.tcoal_2ne * 2 * NE,
            }
        )

inferred_df = (
    pd.DataFrame(inferred_rows).sort_values(["pair", "left"]).reset_index(drop=True)
)
print(f"Total intervals: {len(inferred_df)}")
inferred_df

# %%
inferred_unique_raw = sorted(inferred_df["tcoal_raw"].unique())
inferred_unique_2ne = sorted(inferred_df["tcoal_2ne"].unique())

print(f"Globally unique raw coalescence times: {len(inferred_unique_raw)}")
print(inferred_unique_raw)
print()
print(f"Globally unique t/(2Ne) coalescence times: {len(inferred_unique_2ne)}")
print(inferred_unique_2ne)
print()

inferred_pair_stats = (
    inferred_df.groupby("pair")
    .agg(
        n_intervals=("left", "size"),
        n_unique_times=("tcoal_raw", "nunique"),
        min_tcoal_raw=("tcoal_raw", "min"),
        max_tcoal_raw=("tcoal_raw", "max"),
    )
    .reset_index()
)
print("Per-pair summary (inferred):")
display(inferred_pair_stats)

selected_pair = "0-1"
inferred_pair_times = sorted(
    inferred_df.loc[inferred_df["pair"] == selected_pair, "tcoal_raw"].unique()
)
print(
    f"\nUnique raw times for inferred pair {selected_pair} "
    f"({len(inferred_pair_times)} values):"
)
print(inferred_pair_times)

# %%
selected_pair = "0-1"
truth_pair = df.loc[df["pair"] == selected_pair, ["left", "right", "tcoal_2ne"]]
inferred_pair = inferred_df.loc[
    inferred_df["pair"] == selected_pair, ["left", "right", "tcoal_2ne"]
]

print(f"Truth t/(2Ne) for pair {selected_pair}:")
print(f"  unique values: {sorted(truth_pair['tcoal_2ne'].unique())[:10]} ...")
print(f"  range: {truth_pair['tcoal_2ne'].min():.4f} – {truth_pair['tcoal_2ne'].max():.4f}")
print()
print(f"Inferred t/(2Ne) for pair {selected_pair}:")
print(f"  unique values: {sorted(inferred_pair['tcoal_2ne'].unique())}")
print(f"  range: {inferred_pair['tcoal_2ne'].min():.4f} – {inferred_pair['tcoal_2ne'].max():.4f}")
